# %%
import pandas as pd
from online import MatchingRanking

# %% [markdown]
# Create a queries dict using all three dataset query files

# %%
# List of file paths
query_files = [
    "Datasets/antique/queries/antique-test-queries.txt",
    "Datasets/antique/queries/antique-train-queries.txt"
]

# Initialize an empty dictionary
queries = {}

# Loop through each file
for f in query_files:
    with open(f, 'r') as file:
        for line in file:
            line = line.strip()  # Remove leading/trailing whitespace
            if line:
                identifier, text = line.split('\t', 1)
                queries[identifier] = text

# Now, queries contains data from all three CSV files
print(queries)
# Out:
# {'3990512': 'how can we get concentration onsomething?', '714612': "Why doesn't the water fall off  earth if it's round?", '2528767': 'How do I determine the charge of the iron ion in FeCl3?', '821387': 'I have mice.How do I get rid of them humanely?', '1880028': 'What does "see Leaflet" mean on Ept Pregnancy test?', '4448097': 'what is innate immunity?', '1287437': 'how can i lose 30 pounds by june3?', '2956570': 'What are the words to write the sound of raindrops, moving train & scribbling w/ pencil on paper figuratively?', '1351675': 'Why must I have an uncracked winshield in order to for my car to pass a safety inspeciton?', '1783010': 'What is Blaphsemy?', '2799913': "What's the proper way to express sorrow at a funeral?", '2142044': 'What do you speculate happened to Natalie Holloway in Aruba?', '707303': 'How do people get hiccups, what are they, and what exactly is the best way to cure them?', '676028': 'Why do our elected federal senators and congressmen not have to live on regular S.S. like the rest of us?', '2484180': 'why do people judge a dog by what he looks like?', '2307305': 'Why do man rape little girls?', '2814599': 'what does the word remission mean when referring to cancer patients?', '3369088': 'how can we stop the spread of islam?', '1702151': 'How patient a driver are you?', '851124': 'How is ego a part of our survival instincts?', '3698636': 'why do cats headbutt?', '1844896': 'How to cook Angus burgers?', '2290758': 'Why do people ask questions they know?', '143833': 'What is the difference between coolant and anti-freeze?', '3910925': 'Why is yawning contagious?', '2643507': 'why does milk cost more than gas per gallon?', '1502604': 'how do crooks  make  fake   passports  ?', '4283542': 'i have had loose stools for a week...how do i make it stop?', '3554263': 'why some people behave so rude without reason,is it due to their own problem?', '3313308': 'how can I enjoy my time alone?', '4357460': 'how to make my car faster?', '2582920': 'What is the difference in a dried plum and a dried prune?', '4462511': 'How do i know if my gold fish is pregnant?', '2795030': 'Why do people drink Cuervo when it tastes the same going down as coming up?', '312215': 'how good is apple pie when it is cold?', '3363149': 'Why do Arabs and Mexicans look alike?', '1944018': "Why can't teenagers vote?", '788976': 'Why did the Bush Admin cover up 9/11?', '4385316': 'How do I keep black birds out of my bar-b-que grill?', '551239': 'how do i find out if someone left me a life insurance policy?', '3499881': 'Why is Gordon Ramsey so popular?', '4311093': 'Why hot air rises up?', '4256593': 'How do I remove the SIMM card on a LG VX8300 Cell Phone?', '1017690': 'what is the history of indian music?', '667488': 'how soon can you drive on a newly paved driveway?', '3507491': 'Why is religious freedom more important today?', '2634143': 'what is direct borrowing, phonological borrowing, linguistic borrowing, cultural borrowing,intimate borrowing?', '3396066': 'Why do airplanes fly so high?', '2892478': 'what factors cause the Earth to heat unevenly?', '3155314': 'we have pork chops, veal chops, lamb chops, why is there not any beef chops ?', '785823': 'how is the library consider as a heart of university?', '2815090': 'how cloning will affects our community?', '2713171': "What does the sentence's mean?", '1821193': 'Why do people feed poison (sugar) to their kids on Easter, and why are there no chocolate Jesuses?', '4185501': 'why does the sun shine?', '4473331': 'How can I keep my rabit indoors?', '4190287': 'Why is switching schools so depressing?', '1937374': 'how to get 277 V AC ?', '1459749': "Why don't I have an asthma attack during sex?", '23464': 'why girls are beautiful?', '4377861': 'how to handsew sequins?', '3385681': 'if red bull is soo bad for people ,then why is it soo popular?', '1794677': 'How can I treat my Acne Scars?', '3301173': 'how to design road crust for national highways?', '204633': 'Why do you have memories?' ...

# %% [markdown]
# Create a qrels dict using all three dataset qrels files

# %%
qrels_files = [
    "Datasets/antique/qrels/antique-train.qrel",
    "Datasets/antique/qrels/antique-test.qrel"
]
qrels = {}

for f in qrels_files:
	with open(f, 'r') as file:
		for line in file:
			line = line.strip()
			if line:
				query, none, doc, rel = line.split()
				if query not in qrels.keys():
					qrels[query] = {}
				qrels[query][doc] = rel

# Now, qrels contains data from all three qrels files
print(qrels)
# Out:
# {'2531329': {'2531329_0': '4', '2531329_5': '4', '2531329_4': '3', '2531329_7': '3', '2531329_6': '3', '2531329_1': '2', '2531329_3': '3', '2531329_2': '3'}, '3825668': {'3825668_0': '4', '3825668_4': '4', '3825668_2': '4', '3825668_3': '4', '3825668_1': '4'}, '2146313': {'2146313_0': '4', '2146313_23': '3', '2146313_22': '3', '2146313_21': '4', '2146313_20': '3', '2146313_27': '3', '2146313_26': '3', '2146313_25': '3', '2146313_24': '3', '2146313_29': '3', '2146313_28': '4', '2146313_8': '4', '2146313_9': '4', '2146313_1': '3', '2146313_2': '3', '2146313_3': '2', '2146313_4': '3', '2146313_5': '4', '2146313_6': '3', '2146313_7': '2', '2146313_18': '3', '2146313_19': '4', '2146313_12': '4', '2146313_13': '2', '2146313_10': '2', '2146313_11': '4', '2146313_16': '3', '2146313_17': '3', '2146313_14': '4', '2146313_15': '4'}, '4038667': {'4038667_0': '4', '4038667_26': '3', '4038667_25': '3', '4038667_24': '3', '4038667_23': '3', '4038667_22': '2', '4038667_21': '2', '4038667_20': '4', '4038667_8': '3', '4038667_9': '2', '4038667_4': '3', '4038667_5': '4', '4038667_6': '2', '4038667_7': '3', '4038667_1': '3', '4038667_2': '3', '4038667_3': '3', '4038667_16': '3', '4038667_17': '2', '4038667_14': '3', '4038667_15': '3', '4038667_12': '2', '4038667_13': '2', '4038667_10': '3', '4038667_11': '4', '4038667_18': '3', '4038667_19': '3'}, '2550445': {'2550445_0': '4', '2550445_5': '2', '2550445_4': '3', '2550445_7': '3', '2550445_6': '2', '2550445_1': '2', '2550445_3': '3', '2550445_2': '2'}, '1384464': {'1384464_2': '4', '1384464_8': '4', '1384464_9': '3', '1384464_6': '4', '1384464_7': '4', '1384464_4': '3', '1384464_5': '4', '1384464_3': '3', '1384464_0': '4', '1384464_1': '3'}, '204818': {'204818_8': '4', '204818_10': '4', '204818_11': '4', '204818_9': '3', '204818_0': '3', '204818_1': '3', '204818_2': '4', '204818_3': '3', '204818_4': '3', '204818_5': '4', '204818_6': '4', '204818_7': '4'}, '3751940': {'3751940_0': '4', '3751940_5': '4', '3751940_4': '4', '3751940_7': '2', '3751940_6': '4', '3751940_1': '4', '3751940_3': '4', '3751940_2': '2', '3751940_9': '2', '3751940_8': '2', '3751940_15': '3', '3751940_14': '3', '3751940_17': '4', '3751940_16': '4', '3751940_11': '3', '3751940_10': '4', '3751940_13': '3', '3751940_12': '4'}, '2908187': {'2908187_1': '4', '2908187_9': '3', '2908187_8': '4', '2908187_3': '3', '2908187_2': '3', '2908187_0': '4', '2908187_7': '3', '2908187_6': '3', '2908187_5': '3', '2908187_4': '2', '2908187_10': '4'}, '524318': {'524318_2': '4', '524318_0': '3', '524318_1': '4', '524318_3': '2', '524318_4': '2', '524318_5': '4'}, '1335330': {'1335330_2': '4', '1335330_3': '4', '1335330_0': '4', '1335330_1': '4', '1335330_6': '4', '1335330_4': '4', '1335330_5': '3'}, '639012': {'639012_2': '4', '639012_3': '2', '639012_0': '3', '639012_1': '3', '639012_6': '4', '639012_7': '4', '639012_4': '3', '639012_5': '2'}, '1949736': {'1949736_3': '4', '1949736_5': '4', '1949736_4': '4', '1949736_7': '3', '1949736_6': '3', '1949736_1': '3', '1949736_0': '4', '1949736_2': '4', '1949736_8': '4'}, '4457820': {'4457820_0': '4', '4457820_6': '3', '4457820_7': '4', '4457820_4': '2', '4457820_5': '3', '4457820_2': '3', '4457820_3': '1', '4457820_1': '4', '4457820_8': '2'}, '196651': {'196651_0': '4', '196651_1': '4', '196651_3': '4', '196651_2': '4'}, '417841': {'417841_1': '4', '417841_0': '3', '417841_2': '3'}, '712755': {'712755_1': '4', '712755_8': '3', '712755_9': '4', '712755_2': '4', '712755_3': '3', '712755_0': '3', '712755_6': '4', '712755_7': '4', '712755_4': '3', '712755_5': '3', '712755_10': '3', '712755_11': '2'}, '376888': {'376888_0': '4', '376888_9': '4', '376888_8': '3', '376888_1': '3', '376888_3': '4', '376888_2': '3', '376888_5': '4', '376888_4': '3', '376888_7': '3', '376888_6': '3'}, '3489850': {'3489850_2': '4', '3489850_3': '3', '3489850_1': '3', '3489850_0': '2', '3489850_7': '3', '3489850_6': '4', '3489850_5': '2', '3489850_4': '3', '3489850_8': '2'}, '565308': {'565308_0': '4', '565308_4': '2', '565308_5': ...

# %%
ap_sum = 0.0
rr_sum = 0.0
for query_id, query in queries.items():
	query_id, query = str(query_id), str(query)

	results = MatchingRanking.search("antique", query, 10)

	all_cnt = 0.0
	relevant_cnt = 0.0
	precision = 0.0
	query_rr = 0.0

	for doc_id, doc in results.items():
		doc_id, doc = str(doc_id), str(doc)

		all_cnt += 1.0
		if doc_id in qrels[query_id].keys():
			rel = 1.0 if (int(qrels[query_id][doc_id]) > 1) else 0.0
			if rel == 0.0: continue

			relevant_cnt += 1.0
			precision +=  (relevant_cnt / all_cnt) * rel
			if relevant_cnt == 1.0: query_rr = 1.0 / all_cnt

	query_avg_precision = (precision / relevant_cnt) if relevant_cnt > 0 else 0.0
	ap_sum += query_avg_precision
	rr_sum += query_rr
	# print(query, query_avg_precision)

map_k = ap_sum / len(queries)
mrr = rr_sum / len(queries)
print(f"antique_MAP: {map_k}, antique_MRR: {mrr}")
# Out:
# antique_MAP: 0.27233776597505366, antique_MRR: 0.2959351841777584
